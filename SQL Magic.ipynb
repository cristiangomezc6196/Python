# %%
pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (3.17.0)
# Requirement already satisfied: ipython in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (9.8.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (2.0.45)
# Requirement already satisfied: sqlparse in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import csv 
import sqlite3

# %%
con = sqlite3.connect("SQLiteMagic.db") 
cur = con.cursor()

# %%
# %sql sqlite:///SQLiteMagic.db

# %%
# %%sql
#
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );
# INSERT INTO INTERNATIONAL_STUDENT_TEST_SCORES (country, first_name, last_name, test_score)
# VALUES
# ('United States', 'Marshall', 'Bernadot', 54),
# ('Ghana', 'Celinda', 'Malkin', 51),
# ('Ukraine', 'Guillermo', 'Furze', 53),
# ('Greece', 'Aharon', 'Tunnow', 48),
# ('Russia', 'Bail', 'Goodwin', 46),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 53),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# 99 rows affected.
# []

# %%
pip install ipython-sql prettytable
# Out:
# Requirement already satisfied: ipython-sql in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.17.0)
# Requirement already satisfied: ipython in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (9.8.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (2.0.45)
# Requirement already satisfied: sqlparse in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from prettytable) (0.2.14)
# Requirement already satisfied: greenlet>=1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import prettytable

# %%
prettytable.DEFAULT = "DEFAULT"

# %%
country = "Canada"
# %sql SELECT * FROM INTERNATIONAL_STUDENT_TEST_SCORES WHERE country = :country
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [('Canada', 'Cristionna', 'Wadmore', 46),
#  ('Canada', 'Wilhelm', 'Deeprose', 54),
#  ('Canada', 'Carma', 'Schule', 49)]

# %%
test_score_distribution = %sql SELECT test_score AS "Test_score", count(*) AS "Frecuency" FROM INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score;
test_score_distribution
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [(38, 2),
#  (40, 1),
#  (43, 2),
#  (44, 2),
#  (45, 8),
#  (46, 7),
#  (47, 4),
#  (48, 14),
#  (49, 8),
#  (50, 10),
#  (51, 8),
#  (52, 8),
#  (53, 8),
#  (54, 5),
#  (55, 4),
#  (56, 1),
#  (57, 2),
#  (58, 4),
#  (60, 1)]

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from seaborn) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\canse\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
dataframe = test_score_distribution.DataFrame()
# %matplotlib inline

import seaborn 

plot = seaborn.barplot(x="Test_score", y="Frecuency", data = dataframe)
